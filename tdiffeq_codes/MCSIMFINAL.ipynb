# %%
pip install torchdiffeq
# Out:
# Requirement already satisfied: torchdiffeq in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (0.2.4)
# Requirement already satisfied: torch>=1.5.0 in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from torchdiffeq) (2.2.2)
# Requirement already satisfied: scipy>=1.4.0 in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from torchdiffeq) (1.14.1)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from scipy>=1.4.0->torchdiffeq) (1.26.4)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (4.12.2)
# Requirement already satisfied: sympy in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (1.13.3)
# Requirement already satisfied: networkx in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (3.4.2)
# Requirement already satisfied: jinja2 in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from torch>=1.5.0->torchdiffeq) (2024.10.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from jinja2->torch>=1.5.0->torchdiffeq) (3.0.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages (from sympy->torch>=1.5.0->torchdiffeq) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
#############################

import torchdiffeq

import torch
import torchdiffeq
import numpy as np
import matplotlib.pyplot as plt
import multiprocessing

# Define system parameters
m = 6e4  # mass (kg)
k = 5e6  # 
f = 0.05  # damping ratio
T = 0.69  # natural period (s)
c = 2 * m * f * np.sqrt(k/m)  # damping coefficixent
a = 0.1  # hysteresis parameter
uy = 0.04  # yielding displacement (m)
duration = 8.0  # duration for response calculation (s)

# Bouc-Wen model parameters
A = 1
n = 3  # power for Bouc-Wen
gamma = 1 / (2 * (uy**n))
beta = 1 / (2 * (uy**n))

# Ground acceleration parameters (white noise)
S = 0.005 #0.005
n_freq = 300  # number of frequency points
cutoff_freq = 15 * np.pi  # cutoff frequency (rad/s)
dw = 30 * np.pi / n_freq  # frequency step


class HystereticOscillator(torch.nn.Module):
    def __init__(self, m, c, k, a, A, gamma, beta, n, u_j, u_hat_j):
        super(HystereticOscillator, self).__init__()
        self.m = m
        self.c = c
        self.k = k
        self.a = a
        self.A = A
        self.gamma = gamma
        self.beta = beta
        self.n = n
        self.u_j = u_j
        self.u_hat_j = u_hat_j
        self.time = torch.linspace(0, duration, 400)

        # Convert S and dw to tensors
        self.S = torch.tensor(S, dtype=torch.float32)
        self.dw = torch.tensor(dw, dtype=torch.float32)

    def forward(self, t, state):
        X, V, Z = state
        
        # Ground acceleration
        omega_j = torch.arange(1, (n_freq // 2)+1) * self.dw  # Shape: (n_freq // 2 - 1,)
        sqrt_term = torch.sqrt(2 * self.S * self.dw)  # Scalar

        # Broadcast omega_j with t for cosine and sine terms
        cos_term = torch.cos(omega_j* t)  # Shape: (n_freq // 2 - 1, len(t))
        sin_term = torch.sin(omega_j* t)  # Shape: (n_freq // 2 - 1, len(t))


        # Compute ground_acc
        ground_acc = sqrt_term * (self.u_j * cos_term +
                                  self.u_hat_j * sin_term)

        # ground_acc = ground_acc.sum(dim=0)
        ground_acc = torch.sum(ground_acc)

        
        # Dynamics of the oscillator
        acc = ((-ground_acc * self.m) - (self.c * V) - self.k * (self.a * X + (1 - self.a) * Z)) / self.m
        dZ = (-self.gamma * torch.abs(V) * (torch.abs(Z)**(self.n-1)) * Z - self.beta * (torch.abs(Z)**self.n) * V + self.A * V)
        
        return torch.stack([V, acc, dZ])


# Single simulation function
def run_simulation(x_threshold):
    # Generate random variables for ground motion
    u_j = torch.randn(n_freq // 2)
    u_hat_j = torch.randn(n_freq // 2)

    # Initialize the oscillator
    oscillator = HystereticOscillator(m, c, k, a, A, gamma, beta, n, u_j, u_hat_j)

    # Initial state: [displacement, velocity, hysteresis]
    initial_state = torch.tensor([0.0, 0.0, 0.0])

    # Solve the ODE using torchdiffeq and RK4
    solution = torchdiffeq.odeint(oscillator, initial_state, oscillator.time, method='rk4')

    # Extract the displacement (X) at the last time step
    final_displacement = solution[-1, 0].item()

    # Check if failure occurs
    return final_displacement >= x_threshold

n_iter = 5*(1e4)
fcount = 0; 
for i in range( int(n_iter) ):
    if run_simulation(uy):
        fcount += 1
    if(i%1 == 0):
      print("nfailures :", fcount, " niter:", i+1, "current prob ", fcount/(i+1))

print("prob: ", fcount/n_iter)
# Out:
# nfailures : 0  niter: 1 current prob  0.0
# nfailures : 0  niter: 2 current prob  0.0
# nfailures : 0  niter: 3 current prob  0.0
# nfailures : 0  niter: 4 current prob  0.0
# nfailures : 0  niter: 5 current prob  0.0
# nfailures : 0  niter: 6 current prob  0.0
# nfailures : 0  niter: 7 current prob  0.0
# nfailures : 0  niter: 8 current prob  0.0
# nfailures : 0  niter: 9 current prob  0.0
# nfailures : 0  niter: 10 current prob  0.0
# nfailures : 0  niter: 11 current prob  0.0
# nfailures : 0  niter: 12 current prob  0.0
# nfailures : 0  niter: 13 current prob  0.0
# nfailures : 0  niter: 14 current prob  0.0
# nfailures : 0  niter: 15 current prob  0.0
# nfailures : 0  niter: 16 current prob  0.0
# nfailures : 0  niter: 17 current prob  0.0
# nfailures : 0  niter: 18 current prob  0.0
# nfailures : 0  niter: 19 current prob  0.0
# nfailures : 0  niter: 20 current prob  0.0
# nfailures : 0  niter: 21 current prob  0.0
# nfailures : 0  niter: 22 current prob  0.0
# nfailures : 0  niter: 23 current prob  0.0
# nfailures : 0  niter: 24 current prob  0.0
# nfailures : 0  niter: 25 current prob  0.0
# nfailures : 0  niter: 26 current prob  0.0
# nfailures : 0  niter: 27 current prob  0.0
# nfailures : 0  niter: 28 current prob  0.0
# nfailures : 0  niter: 29 current prob  0.0
# nfailures : 0  niter: 30 current prob  0.0
# nfailures : 0  niter: 31 current prob  0.0
# nfailures : 0  niter: 32 current prob  0.0
# nfailures : 0  niter: 33 current prob  0.0
# nfailures : 0  niter: 34 current prob  0.0
# nfailures : 0  niter: 35 current prob  0.0
# nfailures : 0  niter: 36 current prob  0.0
# nfailures : 0  niter: 37 current prob  0.0
# nfailures : 0  niter: 38 current prob  0.0
# nfailures : 0  niter: 39 current prob  0.0
# nfailures : 0  niter: 40 current prob  0.0
# nfailures : 0  niter: 41 current prob  0.0
# nfailures : 0  niter: 42 current prob  0.0
# nfailures : 0  niter: 43 current prob  0.0
# nfailures : 0  niter: 44 current prob  0.0
# nfailures : 0  niter: 45 current prob  0.0
# nfailures : 0  niter: 46 current prob  0.0
# nfailures : 0  niter: 47 current prob  0.0
# nfailures : 0  niter: 48 current prob  0.0
# nfailures : 0  niter: 49 current prob  0.0
# nfailures : 0  niter: 50 current prob  0.0
# nfailures : 0  niter: 51 current prob  0.0
# nfailures : 0  niter: 52 current prob  0.0
# nfailures : 0  niter: 53 current prob  0.0
# nfailures : 0  niter: 54 current prob  0.0
# nfailures : 0  niter: 55 current prob  0.0
# nfailures : 0  niter: 56 current prob  0.0
# nfailures : 0  niter: 57 current prob  0.0
# nfailures : 0  niter: 58 current prob  0.0
# nfailures : 0  niter: 59 current prob  0.0
# nfailures : 0  niter: 60 current prob  0.0
# nfailures : 0  niter: 61 current prob  0.0
# nfailures : 0  niter: 62 current prob  0.0
# nfailures : 0  niter: 63 current prob  0.0
# nfailures : 0  niter: 64 current prob  0.0
# nfailures : 0  niter: 65 current prob  0.0
# nfailures : 0  niter: 66 current prob  0.0
# nfailures : 0  niter: 67 current prob  0.0
# nfailures : 0  niter: 68 current prob  0.0
# nfailures : 0  niter: 69 current prob  0.0
# nfailures : 0  niter: 70 current prob  0.0
# nfailures : 0  niter: 71 current prob  0.0
# nfailures : 0  niter: 72 current prob  0.0
# nfailures : 0  niter: 73 current prob  0.0
# nfailures : 0  niter: 74 current prob  0.0
# nfailures : 0  niter: 75 current prob  0.0
# nfailures : 0  niter: 76 current prob  0.0
# nfailures : 0  niter: 77 current prob  0.0
# nfailures : 0  niter: 78 current prob  0.0
# nfailures : 0  niter: 79 current prob  0.0
# nfailures : 0  niter: 80 current prob  0.0
# nfailures : 0  niter: 81 current prob  0.0
# nfailures : 0  niter: 82 current prob  0.0
# nfailures : 0  niter: 83 current prob  0.0
# nfailures : 0  niter: 84 current prob  0.0
# nfailures : 0  niter: 85 current prob  0.0
# nfailures : 0  niter: 86 current prob  0.0
# nfailures : 0  niter: 87 current prob  0.0
# nfailures : 0  niter: 88 current prob  0.0
# nfailures : 0  niter: 89 current prob  0.0
# nfailures : 0  niter: 90 current prob  0.0
# nfailures : 0  niter: 91 current prob  0.0
# nfailures : 0  niter: 92 current prob  0.0
# nfailures : 0  niter: 93 current prob  0.0
# nfailures : 0  niter: 94 current prob  0.0
# nfailures : 0  niter: 95 current prob  0.0
# nfailures : 0  niter: 96 current prob  0.0
# nfailures : 0  niter: 97 current prob  0.0
# nfailures : 0  niter: 98 current prob  0.0
# nfailures : 0  niter: 99 current prob  0.0
# nfailures : 0  niter: 100 current prob  0.0
# nfailures : 0  niter: 101 current prob  0.0
# nfailures : 0  niter: 102 current prob  0.0
# nfailures : 0  niter: 103 current prob  0.0
# nfailures : 0  niter: 104 current prob  0.0
# nfailures : 0  niter: 105 current prob  0.0
# nfailures : 0  niter: 106 current prob  0.0
# nfailures : 0  niter: 107 current prob  0.0
# nfailures : 0  niter: 108 current prob  0.0
# nfailures : 0  niter: 109 current prob  0.0
# nfailures : 0  niter: 110 current prob  0.0
# nfailures : 0  niter: 111 current prob  0.0
# nfailures : 0  niter: 112 current prob  0.0
# nfailures : 0  niter: 113 current prob  0.0
# nfailures : 0  niter: 114 current prob  0.0
# nfailures : 0  niter: 115 current prob  0.0
# nfailures : 0  niter: 116 current prob  0.0
# nfailures : 0  niter: 117 current prob  0.0
# nfailures : 0  niter: 118 current prob  0.0
# nfailures : 0  niter: 119 current prob  0.0
# nfailures : 0  niter: 120 current prob  0.0
# nfailures : 0  niter: 121 current prob  0.0
# nfailures : 0  niter: 122 current prob  0.0
# nfailures : 0  niter: 123 current prob  0.0
# nfailures : 0  niter: 124 current prob  0.0
# nfailures : 0  niter: 125 current prob  0.0
# nfailures : 0  niter: 126 current prob  0.0
# nfailures : 0  niter: 127 current prob  0.0
# nfailures : 0  niter: 128 current prob  0.0
# nfailures : 0  niter: 129 current prob  0.0
# nfailures : 0  niter: 130 current prob  0.0
# nfailures : 0  niter: 131 current prob  0.0
# nfailures : 0  niter: 132 current prob  0.0
# nfailures : 0  niter: 133 current prob  0.0
# nfailures : 0  niter: 134 current prob  0.0
# nfailures : 0  niter: 135 current prob  0.0
# nfailures : 0  niter: 136 current prob  0.0
# nfailures : 0  niter: 137 current prob  0.0
# nfailures : 0  niter: 138 current prob  0.0
# nfailures : 0  niter: 139 current prob  0.0
# nfailures : 0  niter: 140 current prob  0.0
# nfailures : 0  niter: 141 current prob  0.0
# nfailures : 0  niter: 142 current prob  0.0
# nfailures : 0  niter: 143 current prob  0.0
# nfailures : 0  niter: 144 current prob  0.0
# nfailures : 0  niter: 145 current prob  0.0
# nfailures : 0  niter: 146 current prob  0.0
# nfailures : 0  niter: 147 current prob  0.0
# nfailures : 0  niter: 148 current prob  0.0
# nfailures : 0  niter: 149 current prob  0.0
# nfailures : 0  niter: 150 current prob  0.0
# nfailures : 0  niter: 151 current prob  0.0
# nfailures : 0  niter: 152 current prob  0.0
# nfailures : 0  niter: 153 current prob  0.0
# nfailures : 0  niter: 154 current prob  0.0
# nfailures : 0  niter: 155 current prob  0.0
# nfailures : 0  niter: 156 current prob  0.0
# nfailures : 0  niter: 157 current prob  0.0
# nfailures : 0  niter: 158 current prob  0.0
# nfailures : 0  niter: 159 current prob  0.0
# nfailures : 0  niter: 160 current prob  0.0
# nfailures : 0  niter: 161 current prob  0.0
# nfailures : 0  niter: 162 current prob  0.0
# nfailures : 0  niter: 163 current prob  0.0
# nfailures : 0  niter: 164 current prob  0.0
# nfailures : 0  niter: 165 current prob  0.0
# nfailures : 0  niter: 166 current prob  0.0
# nfailures : 0  niter: 167 current prob  0.0
# nfailures : 0  niter: 168 current prob  0.0
# nfailures : 0  niter: 169 current prob  0.0
# nfailures : 0  niter: 170 current prob  0.0
# nfailures : 0  niter: 171 current prob  0.0
# nfailures : 0  niter: 172 current prob  0.0
# nfailures : 0  niter: 173 current prob  0.0
# nfailures : 0  niter: 174 current prob  0.0
# nfailures : 0  niter: 175 current prob  0.0
# nfailures : 0  niter: 176 current prob  0.0
# nfailures : 0  niter: 177 current prob  0.0
# nfailures : 0  niter: 178 current prob  0.0
# nfailures : 0  niter: 179 current prob  0.0
# nfailures : 0  niter: 180 current prob  0.0
# nfailures : 0  niter: 181 current prob  0.0
# nfailures : 0  niter: 182 current prob  0.0
# nfailures : 0  niter: 183 current prob  0.0
# nfailures : 0  niter: 184 current prob  0.0
# nfailures : 0  niter: 185 current prob  0.0
# nfailures : 0  niter: 186 current prob  0.0
# nfailures : 0  niter: 187 current prob  0.0
# nfailures : 0  niter: 188 current prob  0.0
# nfailures : 0  niter: 189 current prob  0.0
# nfailures : 0  niter: 190 current prob  0.0
# nfailures : 0  niter: 191 current prob  0.0
# nfailures : 0  niter: 192 current prob  0.0
# nfailures : 0  niter: 193 current prob  0.0
# nfailures : 0  niter: 194 current prob  0.0
# nfailures : 0  niter: 195 current prob  0.0
# nfailures : 0  niter: 196 current prob  0.0
# nfailures : 0  niter: 197 current prob  0.0
# nfailures : 0  niter: 198 current prob  0.0
# nfailures : 0  niter: 199 current prob  0.0
# nfailures : 0  niter: 200 current prob  0.0
# nfailures : 0  niter: 201 current prob  0.0
# nfailures : 0  niter: 202 current prob  0.0
# nfailures : 0  niter: 203 current prob  0.0
# nfailures : 0  niter: 204 current prob  0.0
# nfailures : 0  niter: 205 current prob  0.0
# nfailures : 0  niter: 206 current prob  0.0
# nfailures : 0  niter: 207 current prob  0.0
# nfailures : 0  niter: 208 current prob  0.0
# nfailures : 0  niter: 209 current prob  0.0
# nfailures : 0  niter: 210 current prob  0.0
# nfailures : 0  niter: 211 current prob  0.0
# nfailures : 0  niter: 212 current prob  0.0
# nfailures : 0  niter: 213 current prob  0.0
# nfailures : 0  niter: 214 current prob  0.0
# nfailures : 0  niter: 215 current prob  0.0
# nfailures : 0  niter: 216 current prob  0.0
# nfailures : 0  niter: 217 current prob  0.0
# nfailures : 0  niter: 218 current prob  0.0
# nfailures : 0  niter: 219 current prob  0.0
# nfailures : 0  niter: 220 current prob  0.0
# nfailures : 0  niter: 221 current prob  0.0
# nfailures : 0  niter: 222 current prob  0.0
# nfailures : 0  niter: 223 current prob  0.0
# nfailures : 0  niter: 224 current prob  0.0
# nfailures : 0  niter: 225 current prob  0.0
# nfailures : 0  niter: 226 current prob  0.0
# nfailures : 0  niter: 227 current prob  0.0
# nfailures : 0  niter: 228 current prob  0.0
# nfailures : 0  niter: 229 current prob  0.0
# nfailures : 0  niter: 230 current prob  0.0
# nfailures : 0  niter: 231 current prob  0.0
# nfailures : 0  niter: 232 current prob  0.0
# nfailures : 0  niter: 233 current prob  0.0
# nfailures : 0  niter: 234 current prob  0.0
# nfailures : 0  niter: 235 current prob  0.0
# nfailures : 0  niter: 236 current prob  0.0
# nfailures : 0  niter: 237 current prob  0.0
# nfailures : 0  niter: 238 current prob  0.0
# nfailures : 0  niter: 239 current prob  0.0
# nfailures : 0  niter: 240 current prob  0.0
# nfailures : 0  niter: 241 current prob  0.0
# nfailures : 0  niter: 242 current prob  0.0
# nfailures : 0  niter: 243 current prob  0.0
# nfailures : 0  niter: 244 current prob  0.0
# nfailures : 0  niter: 245 current prob  0.0
# nfailures : 0  niter: 246 current prob  0.0
# nfailures : 0  niter: 247 current prob  0.0
# nfailures : 0  niter: 248 current prob  0.0
# nfailures : 0  niter: 249 current prob  0.0
# nfailures : 0  niter: 250 current prob  0.0
# nfailures : 0  niter: 251 current prob  0.0
# nfailures : 0  niter: 252 current prob  0.0
# nfailures : 0  niter: 253 current prob  0.0
# nfailures : 0  niter: 254 current prob  0.0
# nfailures : 0  niter: 255 current prob  0.0
# nfailures : 0  niter: 256 current prob  0.0
# nfailures : 0  niter: 257 current prob  0.0
# nfailures : 0  niter: 258 current prob  0.0
# nfailures : 0  niter: 259 current prob  0.0
# nfailures : 0  niter: 260 current prob  0.0
# nfailures : 0  niter: 261 current prob  0.0
# nfailures : 0  niter: 262 current prob  0.0
# nfailures : 0  niter: 263 current prob  0.0
# nfailures : 0  niter: 264 current prob  0.0
# nfailures : 0  niter: 265 current prob  0.0
# nfailures : 0  niter: 266 current prob  0.0
# nfailures : 0  niter: 267 current prob  0.0
# nfailures : 0  niter: 268 current prob  0.0
# nfailures : 0  niter: 269 current prob  0.0
# nfailures : 0  niter: 270 current prob  0.0
# nfailures : 0  niter: 271 current prob  0.0
# nfailures : 0  niter: 272 current prob  0.0
# nfailures : 0  niter: 273 current prob  0.0
# nfailures : 0  niter: 274 current prob  0.0
# nfailures : 0  niter: 275 current prob  0.0
# nfailures : 0  niter: 276 current prob  0.0
# nfailures : 0  niter: 277 current prob  0.0
# nfailures : 0  niter: 278 current prob  0.0
# nfailures : 0  niter: 279 current prob  0.0
# nfailures : 0  niter: 280 current prob  0.0
# nfailures : 0  niter: 281 current prob  0.0
# nfailures : 0  niter: 282 current prob  0.0
# nfailures : 0  niter: 283 current prob  0.0
# nfailures : 0  niter: 284 current prob  0.0
# nfailures : 0  niter: 285 current prob  0.0
# nfailures : 0  niter: 286 current prob  0.0
# nfailures : 0  niter: 287 current prob  0.0
# nfailures : 0  niter: 288 current prob  0.0
# nfailures : 0  niter: 289 current prob  0.0
# nfailures : 0  niter: 290 current prob  0.0
# nfailures : 0  niter: 291 current prob  0.0
# nfailures : 0  niter: 292 current prob  0.0
# nfailures : 0  niter: 293 current prob  0.0
# nfailures : 0  niter: 294 current prob  0.0
# nfailures : 0  niter: 295 current prob  0.0
# nfailures : 0  niter: 296 current prob  0.0
# nfailures : 0  niter: 297 current prob  0.0
# nfailures : 0  niter: 298 current prob  0.0
# nfailures : 0  niter: 299 current prob  0.0
# nfailures : 0  niter: 300 current prob  0.0
# nfailures : 0  niter: 301 current prob  0.0
# nfailures : 0  niter: 302 current prob  0.0
# nfailures : 0  niter: 303 current prob  0.0
# nfailures : 0  niter: 304 current prob  0.0
# nfailures : 0  niter: 305 current prob  0.0
# nfailures : 0  niter: 306 current prob  0.0
# nfailures : 0  niter: 307 current prob  0.0
# nfailures : 0  niter: 308 current prob  0.0
# nfailures : 0  niter: 309 current prob  0.0
# nfailures : 0  niter: 310 current prob  0.0
# nfailures : 0  niter: 311 current prob  0.0
# nfailures : 0  niter: 312 current prob  0.0
# nfailures : 0  niter: 313 current prob  0.0
# nfailures : 0  niter: 314 current prob  0.0
# nfailures : 0  niter: 315 current prob  0.0
# nfailures : 0  niter: 316 current prob  0.0
# nfailures : 0  niter: 317 current prob  0.0
# nfailures : 0  niter: 318 current prob  0.0
# nfailures : 0  niter: 319 current prob  0.0
# nfailures : 0  niter: 320 current prob  0.0
# nfailures : 0  niter: 321 current prob  0.0
# nfailures : 0  niter: 322 current prob  0.0
# nfailures : 0  niter: 323 current prob  0.0
# nfailures : 0  niter: 324 current prob  0.0
# nfailures : 0  niter: 325 current prob  0.0
# nfailures : 0  niter: 326 current prob  0.0
# nfailures : 0  niter: 327 current prob  0.0
# nfailures : 0  niter: 328 current prob  0.0
# nfailures : 0  niter: 329 current prob  0.0
# nfailures : 0  niter: 330 current prob  0.0
# nfailures : 0  niter: 331 current prob  0.0
# nfailures : 0  niter: 332 current prob  0.0
# nfailures : 0  niter: 333 current prob  0.0
# nfailures : 0  niter: 334 current prob  0.0
# nfailures : 0  niter: 335 current prob  0.0
# nfailures : 0  niter: 336 current prob  0.0
# nfailures : 0  niter: 337 current prob  0.0
# nfailures : 0  niter: 338 current prob  0.0
# nfailures : 0  niter: 339 current prob  0.0
# nfailures : 0  niter: 340 current prob  0.0
# nfailures : 0  niter: 341 current prob  0.0
# nfailures : 0  niter: 342 current prob  0.0
# nfailures : 0  niter: 343 current prob  0.0
# nfailures : 0  niter: 344 current prob  0.0
# nfailures : 0  niter: 345 current prob  0.0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 104
#     102 fcount = 0;
#     103 for i in range( int(n_iter) ):
# --> 104     if run_simulation(uy):
#     105         fcount += 1
#     106     if(i%1 == 0):
#
# Cell In[1], line 93, in run_simulation(x_threshold)
#      90 initial_state = torch.tensor([0.0, 0.0, 0.0])
#      92 # Solve the ODE using torchdiffeq and RK4
# ---> 93 solution = torchdiffeq.odeint(oscillator, initial_state, oscillator.time, method='rk4')
#      95 # Extract the displacement (X) at the last time step
#      96 final_displacement = solution[-1, 0].item()
#
# File /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages/torchdiffeq/_impl/odeint.py:79, in odeint(func, y0, t, rtol, atol, method, options, event_fn)
#      76 solver = SOLVERS[method](func=func, y0=y0, rtol=rtol, atol=atol, **options)
#      78 if event_fn is None:
# ---> 79     solution = solver.integrate(t)
#      80 else:
#      81     event_t, solution = solver.integrate_until_event(t[0], event_fn)
#
# File /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages/torchdiffeq/_impl/solvers.py:114, in FixedGridODESolver.integrate(self, t)
#     112 dt = t1 - t0
#     113 self.func.callback_step(t0, y0, dt)
# --> 114 dy, f0 = self._step_func(self.func, t0, dt, t1, y0)
#     115 y1 = y0 + dy
#     117 while j < len(t) and t1 >= t[j]:
#
# File /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages/torchdiffeq/_impl/fixed_grid.py:29, in RK4._step_func(self, func, t0, dt, t1, y0)
#      27 def _step_func(self, func, t0, dt, t1, y0):
#      28     f0 = func(t0, y0, perturb=Perturb.NEXT if self.perturb else Perturb.NONE)
# ---> 29     return rk4_alt_step_func(func, t0, dt, t1, y0, f0=f0, perturb=self.perturb), f0
#
# File /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages/torchdiffeq/_impl/rk_common.py:113, in rk4_alt_step_func(func, t0, dt, t1, y0, f0, perturb)
#     111 if k1 is None:
#     112     k1 = func(t0, y0, perturb=Perturb.NEXT if perturb else Perturb.NONE)
# --> 113 k2 = func(t0 + dt * _one_third, y0 + dt * k1 * _one_third)
#     114 k3 = func(t0 + dt * _two_thirds, y0 + dt * (k2 - k1 * _one_third))
#     115 k4 = func(t1, y0 + dt * (k1 - k2 + k3), perturb=Perturb.PREV if perturb else Perturb.NONE)
#
# File /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages/torchdiffeq/_impl/misc.py:197, in _PerturbFunc.forward(self, t, y, perturb)
#     194 else:
#     195     # Do nothing.
#     196     pass
# --> 197 return self.base_func(t, y)
#
# File /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/envs/btpenv/lib/python3.11/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# Cell In[1], line 58, in HystereticOscillator.forward(self, t, state)
#      56 # Ground acceleration
#      57 omega_j = torch.arange(1, (n_freq // 2)+1) * self.dw  # Shape: (n_freq // 2 - 1,)
# ---> 58 sqrt_term = torch.sqrt(2 * self.S * self.dw)  # Scalar
#      60 # Broadcast omega_j with t for cosine and sine terms
#      61 cos_term = torch.cos(omega_j* t)  # Shape: (n_freq // 2 - 1, len(t))
#
# KeyboardInterrupt:
